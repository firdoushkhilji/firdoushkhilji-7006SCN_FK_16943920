# %% [markdown]
# <a href="https://colab.research.google.com/github/firdoushkhilji/firdoushkhilji-7006SCN_FK_16943920/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('/content/drive/MyDrive/')
# Out:
# ['TASK_DATASET', 'Colab Notebooks']

# %%
os.listdir('/content/drive/MyDrive/TASK_DATASET/')
# Out:
# ['epd_snomed_202603.csv']

# %%
#import and start pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("NHS_Prescription_Cost_Prediction") \
    .getOrCreate()

print('Spark Successfully Started!')
# Out:
# Spark Successfully Started!

# %%
df = spark.read.csv('/content/drive/MyDrive/TASK_DATASET/epd_snomed_202603.csv', header=True, inferSchema=True)

# %%
print('Top 20 Records - \n')
df.show(20)
# Out:
# Top Records -
#
# +-------------------+--------------------+--------------------+--------------------+--------+--------------------+--------+-------------------+-------------+-------------------+---------------+-------------------+---------+--------+---------------------------+----------------------+---------------------+---------------------+---------------------+--------+-----+--------------+---------+-----+-----------+------------+-----------------+
# |         YEAR_MONTH|REGIONAL_OFFICE_NAME|REGIONAL_OFFICE_CODE|            ICB_NAME|ICB_CODE|            PCO_NAME|PCO_CODE|      PRACTICE_NAME|PRACTICE_CODE|          ADDRESS_1|      ADDRESS_2|          ADDRESS_3|ADDRESS_4|POSTCODE|BNF_CHEMICAL_SUBSTANCE_CODE|BNF_CHEMICAL_SUBSTANCE|BNF_PRESENTATION_CODE|BNF_PRESENTATION_NAME|BNF_CHAPTER_PLUS_CODE|QUANTITY|ITEMS|TOTAL_QUANTITY|ADQ_USAGE|  NIC|ACTUAL_COST|UNIDENTIFIED|      SNOMED_CODE|
# +-------------------+--------------------+--------------------+--------------------+--------+--------------------+--------+-------------------+-------------+-------------------+---------------+-------------------+---------+--------+---------------------------+----------------------+---------------------+---------------------+---------------------+--------+-----+--------------+---------+-----+-----------+------------+-----------------+
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0405010P0|              Orlistat|      0405010P0AAAAAA| Orlistat 120mg ca...| 04: Central Nervo...|   224.0|    1|         224.0| 74.66667|44.67|   35.83054|           N|42356811000001100|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000P0|  Metoclopramide hy...|      0406000P0AAADAD| Metoclopramide 5m...| 04: Central Nervo...|   150.0|    1|         150.0|      5.0| 7.99|     8.0024|           N|39111811000001102|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000P0|  Metoclopramide hy...|      0406000P0AAAEAE| Metoclopramide 10...| 04: Central Nervo...|    28.0|    2|          56.0| 18.66667| 1.36|    1.11226|           N|42037611000001102|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000S0|  Ondansetron hydro...|      0406000S0AAABAB| Ondansetron 4mg t...| 04: Central Nervo...|    10.0|    1|          10.0|      2.5|  1.4|    1.13184|           N|42038611000001103|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000S0|  Ondansetron hydro...|      0406000S0AAABAB| Ondansetron 4mg t...| 04: Central Nervo...|    30.0|    1|          30.0|      7.5|  4.2|    3.37072|           N|42038611000001103|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000S0|  Ondansetron hydro...|      0406000S0AAACAC| Ondansetron 8mg t...| 04: Central Nervo...|    60.0|    1|          60.0|     30.0|22.44|    22.4524|           N|39701611000001108|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000S0|  Ondansetron hydro...|      0406000S0AAAGAG| Ondansetron 4mg/5...| 04: Central Nervo...|   200.0|    2|         400.0|     20.0|58.56|    58.5848|           N|36564311000001109|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000S0|  Ondansetron hydro...|      0406000S0AAAGAG| Ondansetron 4mg/5...| 04: Central Nervo...|    50.0|    1|          50.0|      2.5| 7.32|     7.3324|           N|36564311000001109|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000S0|  Ondansetron hydro...|      0406000S0AAAKAK| Ondansetron 4mg o...| 04: Central Nervo...|    20.0|    1|          20.0|      5.0|69.92|    69.9324|           N|42038511000001102|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAGAG| Prochlorperazine ...| 04: Central Nervo...|    28.0|   10|         280.0|    140.0|  7.7|    6.28092|           N|42040311000001105|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAGAG| Prochlorperazine ...| 04: Central Nervo...|    56.0|    2|         112.0|     56.0| 3.08|    2.48757|           N|42040311000001105|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAGAG| Prochlorperazine ...| 04: Central Nervo...|    84.0|    2|         168.0|     84.0| 4.62|    3.71895|           N|42040311000001105|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAGAG| Prochlorperazine ...| 04: Central Nervo...|    21.0|    1|          21.0|     10.5| 0.58|    0.57617|           N|42040311000001105|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAGAG| Prochlorperazine ...| 04: Central Nervo...|    15.0|    1|          15.0|      7.5| 0.41|    0.44024|           N|42040311000001105|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAKAK| Prochlorperazine ...| 04: Central Nervo...|    28.0|    1|          28.0|  9.33333|  7.2|    5.86952|           N|42040011000001107|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAKAK| Prochlorperazine ...| 04: Central Nervo...|     8.0|    3|          24.0|      8.0| 6.18|    5.27873|           N|42040011000001107|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAKAK| Prochlorperazine ...| 04: Central Nervo...|    14.0|    2|          28.0|  9.33333|  7.2|    5.98192|           N|42040011000001107|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAKAK| Prochlorperazine ...| 04: Central Nervo...|    25.0|    1|          25.0|  8.33333| 6.43|    5.25383|           N|42040011000001107|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAKAK| Prochlorperazine ...| 04: Central Nervo...|    50.0|    1|          50.0| 16.66667|12.85|   10.28726|           N|42040011000001107|
# |2026-03-01 00:00:00|            MIDLANDS|                 Y60|NHS COVENTRY AND ...|     QWU|NHS COVENTRY AND ...|   B2M3M|ST WULFSTAN SURGERY|       M84629|ST WULFSTAN SURGERY|NORTHFIELD ROAD|KINETON ROAD ESTATE|  SOUTHAM|CV47 0FG|                  0406000T0|  Prochlorperazine ...|      0406000T0AAAKAK| Prochlorperazine ...| 04: Central Nervo...|    16.0|    1|          16.0|  5.33333| 4.11|    3.39876|           N|42040011000001107|
# +-------------------+--------------------+--------------------+--------------------+--------+--------------------+--------+-------------------+-------------+-------------------+---------------+-------------------+---------+--------+---------------------------+----------------------+---------------------+---------------------+---------------------+--------+-----+--------------+---------+-----+-----------+------------+-----------------+
# only showing top 20 rows

# %%
print('Description of Dataset -\n')
df.printSchema()
# Out:
# Description of Dataset -
#
# root
#  |-- YEAR_MONTH: timestamp (nullable = true)
#  |-- REGIONAL_OFFICE_NAME: string (nullable = true)
#  |-- REGIONAL_OFFICE_CODE: string (nullable = true)
#  |-- ICB_NAME: string (nullable = true)
#  |-- ICB_CODE: string (nullable = true)
#  |-- PCO_NAME: string (nullable = true)
#  |-- PCO_CODE: string (nullable = true)
#  |-- PRACTICE_NAME: string (nullable = true)
#  |-- PRACTICE_CODE: string (nullable = true)
#  |-- ADDRESS_1: string (nullable = true)
#  |-- ADDRESS_2: string (nullable = true)
#  |-- ADDRESS_3: string (nullable = true)
#  |-- ADDRESS_4: string (nullable = true)
#  |-- POSTCODE: string (nullable = true)
#  |-- BNF_CHEMICAL_SUBSTANCE_CODE: string (nullable = true)
#  |-- BNF_CHEMICAL_SUBSTANCE: string (nullable = true)
#  |-- BNF_PRESENTATION_CODE: string (nullable = true)
#  |-- BNF_PRESENTATION_NAME: string (nullable = true)
#  |-- BNF_CHAPTER_PLUS_CODE: string (nullable = true)
#  |-- QUANTITY: double (nullable = true)
#  |-- ITEMS: integer (nullable = true)
#  |-- TOTAL_QUANTITY: double (nullable = true)
#  |-- ADQ_USAGE: double (nullable = true)
#  |-- NIC: double (nullable = true)
#  |-- ACTUAL_COST: double (nullable = true)
#  |-- UNIDENTIFIED: string (nullable = true)
#  |-- SNOMED_CODE: long (nullable = true)
